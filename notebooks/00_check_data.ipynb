# %% [markdown]
# # 00 — Check StatsBomb Data Availability
#
# Run this first to see exactly which competitions and seasons are available.
# Note down the `competition_id` and `season_id` you want to use.

# %%
from statsbombpy import sb
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 20)

# %%
# Load all available competitions
competitions = sb.competitions()
print(f'Total competitions available: {len(competitions)}')
competitions[['competition_name', 'season_name', 'competition_id', 'season_id', 'competition_gender']].sort_values(['competition_name', 'season_name'])
# Out:
# c:\tb-scouting\venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Total competitions available: 75
#            competition_name season_name  competition_id  season_id  \
# 1             1. Bundesliga   2015/2016               9         27
# 0             1. Bundesliga   2023/2024               9        281
# 2    African Cup of Nations        2023            1267        107
# 20         Champions League   1970/1971              16        276
# 19         Champions League   1971/1972              16         71
# 18         Champions League   1972/1973              16        277
# 17         Champions League   1999/2000              16         76
# 16         Champions League   2003/2004              16         44
# 15         Champions League   2004/2005              16         37
# 14         Champions League   2006/2007              16         39
# ...

# %%
# Filter to men's competitions only
mens = competitions[competitions['competition_gender'] == 'male']
print(f'Men competitions: {len(mens)}')
mens[['competition_name', 'season_name', 'competition_id', 'season_id']]
# Out:
# Men competitions: 67
#           competition_name season_name  competition_id  season_id
# 0            1. Bundesliga   2023/2024               9        281
# 1            1. Bundesliga   2015/2016               9         27
# 2   African Cup of Nations        2023            1267        107
# 3         Champions League   2018/2019              16          4
# 4         Champions League   2017/2018              16          1
# 5         Champions League   2016/2017              16          2
# 6         Champions League   2015/2016              16         27
# 7         Champions League   2014/2015              16         26
# 8         Champions League   2013/2014              16         25
# 9         Champions League   2012/2013              16         24
# 10        Champions League   2011/2012              16         23
# 11        Champions League   2010/2011              16         22
# 12        Champions League   2009/2010              16         21
# ...

# %%
# Count matches per competition to see which are most data-rich
for _, row in mens.iterrows():
    try:
        matches = sb.matches(competition_id=row['competition_id'], season_id=row['season_id'])
        print(f"{row['competition_name']} {row['season_name']}: {len(matches)} matches (comp_id={row['competition_id']}, season_id={row['season_id']})")
    except:
        print(f"{row['competition_name']} {row['season_name']}: ERROR")
# Out:
# c:\tb-scouting\venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 1. Bundesliga 2023/2024: 34 matches (comp_id=9, season_id=281)
# c:\tb-scouting\venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 1. Bundesliga 2015/2016: 306 matches (comp_id=9, season_id=27)
# c:\tb-scouting\venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# African Cup of Nations 2023: 52 matches (comp_id=1267, season_id=107)
# c:\tb-scouting\venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Champions League 2018/2019: 1 matches (comp_id=16, season_id=4)
# ...

# %% [markdown]
# ## Your chosen competitions
# Fill this in after running the cells above:

# %%
# ← FILL THIS IN after checking availability above
COMPETITIONS_TO_USE = [
    {'name': 'La Liga 2015/16',        'competition_id': 11, 'season_id': 27},
    {'name': 'Premier League 2015/16', 'competition_id': 2,  'season_id': 27},
    {'name': 'Bundesliga 2015/16',     'competition_id': 9,  'season_id': 27},
    {'name': 'Ligue 1 2015/16',        'competition_id': 7,  'season_id': 27},
    {'name': 'Serie A 2015/16',        'competition_id': 12, 'season_id': 27},
]

print('Competitions selected:')
for c in COMPETITIONS_TO_USE:
    print(f"  - {c['name']}")
# Out:
# Competitions selected:
#   - La Liga 2015/16
#   - Premier League 2015/16
#   - Bundesliga 2015/16
#   - Ligue 1 2015/16
#   - Serie A 2015/16
